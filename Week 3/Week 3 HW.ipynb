# %%
import pandas as pd
import json
from datetime import datetime
import numpy as np

# %%
#HW 1: Convert JSON File to a dataframe

#Open the json file and make it a python dictionary
with open('week3_homework.json') as f:
    txt = json.load(f)

# %%
txt.get('gameLog')

# %%
#Convert all of the repeating information to dataframe

df=pd.DataFrame(txt['gameLog'][0]['eventSequence'])

# %%
#Add the info at the top level to the dataframe
df['sessionID']=txt['gameLog'][0]['sessionID'] 
df['teamID']=txt['gameLog'][0]['teamID']
df['attemptID']=txt['gameLog'][0]['attemptID'] 
df['n_player']=txt['gameLog'][0]['sessionExtData']['n_player']
df['team_assembly_mode']=txt['gameLog'][0]['sessionExtData']['team_assembly_mode']

#Could probably do this with a function but not sure how?
a =  { 'jiangang' : 'jiangang',  'hao' : 'hao'}
b =  { 'jiangang' : 'P1',  'hao' : 'P2'}
df['userID'] = df['eventBy'].map(a)
df['nickname'] = df['eventBy'].map(a)
df['player'] = df['userID'].map(b)

#reorder dataframe columns
df2=df[["sessionID", "teamID", "userID", "nickname", "attemptID", "n_player", "team_assembly_mode", "player", "eventName", "eventStartTime"\
       , "eventEndTime", "eventBy", "eventTo", "eventResult", "eventLocation", "eventExtData"]]

#print to check
df2.head(n=10)
# Out:
#   sessionID        teamID    userID  nickname  attemptID  n_player  \
# 0      7369  hao_jiangang  jiangang  jiangang         17         2
# 1      7369  hao_jiangang  jiangang  jiangang         17         2
# 2      7369  hao_jiangang  jiangang  jiangang         17         2
# 3      7369  hao_jiangang  jiangang  jiangang         17         2
# 4      7369  hao_jiangang  jiangang  jiangang         17         2
# 5      7369  hao_jiangang  jiangang  jiangang         17         2
# 6      7369  hao_jiangang       NaN       NaN         17         2
# 7      7369  hao_jiangang       hao       hao         17         2
# 8      7369  hao_jiangang       hao       hao         17         2
# 9      7369  hao_jiangang  jiangang  jiangang         17         2
#
#   team_assembly_mode player eventName        eventStartTime  \
# 0             random     P1      chat  2019-11-06T14:18:31Z
# 1             random     P1  question  2019-11-06T14:18:42Z
# ...

# %%
#HW 2: Convert XML File to a dataframe and then output as a csv

#parse out the top level information
top = pd.read_xml('week3_homework.xml')
top
# Out:
#    sessionID        teamID  playerID  attemptID  sessionExtData  eventSequence
# 0       7369  hao_jiangang       NaN         17             NaN            NaN

# %%
#parse out the repeating sequence
Events = pd.read_xml('week3_homework.xml', xpath=".//eventSequence/*")
Events.head(10)
# Out:
#   eventName        eventStartTime          eventEndTime   eventBy   eventTo  \
# 0      chat  2019-11-06T14:18:31Z  2019-11-06T14:18:31Z  jiangang    others
# 1  question  2019-11-06T14:18:42Z  2019-11-06T14:18:42Z  jiangang  cbal-1-0
# 2  question  2019-11-06T14:18:42Z  2019-11-06T14:18:42Z  jiangang  cbal-1-1
# 3      chat  2019-11-06T14:18:44Z  2019-11-06T14:18:44Z  jiangang    others
# 4      chat  2019-11-06T14:18:46Z  2019-11-06T14:18:46Z  jiangang    others
# 5      chat  2019-11-06T14:18:49Z  2019-11-06T14:18:49Z  jiangang    others
# 6      chat  2019-11-06T14:18:50Z  2019-11-06T14:18:50Z    system  jiangang
# 7  question  2019-11-06T14:18:56Z  2019-11-06T14:18:56Z       hao  cbal-1-1
# 8  question  2019-11-06T14:18:56Z  2019-11-06T14:18:56Z       hao  cbal-1-0
# 9      chat  2019-11-06T14:18:59Z  2019-11-06T14:18:59Z  jiangang    others
#
#                                          eventResult eventLocation  \
# ...

# %%
#merge together
result = top.merge(Events, how="cross")
#result = top.assign(key=1).merge(Events.assign(key=1), how='outer', on='key')
result.head(10)
# Out:
#    sessionID        teamID  playerID  attemptID  sessionExtData  \
# 0       7369  hao_jiangang       NaN         17             NaN
# 1       7369  hao_jiangang       NaN         17             NaN
# 2       7369  hao_jiangang       NaN         17             NaN
# 3       7369  hao_jiangang       NaN         17             NaN
# 4       7369  hao_jiangang       NaN         17             NaN
# 5       7369  hao_jiangang       NaN         17             NaN
# 6       7369  hao_jiangang       NaN         17             NaN
# 7       7369  hao_jiangang       NaN         17             NaN
# 8       7369  hao_jiangang       NaN         17             NaN
# 9       7369  hao_jiangang       NaN         17             NaN
#
#    eventSequence eventName        eventStartTime          eventEndTime  \
# 0            NaN      chat  2019-11-06T14:18:31Z  2019-11-06T14:18:31Z
# 1            NaN  question  2019-11-06T14:18:42Z  2019-11-06T14:18:42Z
# ...

# %%
#PlayerID is still missing, we need to merge it in  
playerID  = pd.read_xml('week3_homework.xml', xpath=".//playerID/*")
playerID
# Out:
#          key     value
# 0    userID1  jiangang
# 1  nickname1  jiangang
# 2    userID2       hao
# 3  nickname2       hao

# %%
#Im unsure how to get from there to here so i did it manually. 
a =  { 'jiangang' : 'jiangang',  'hao' : 'hao'}
b =  { 'jiangang' : 'P1',  'hao' : 'P2'}
result['userID'] = result['eventBy'].map(a)
result['nickname'] = result['eventBy'].map(a)
result['player'] = result['userID'].map(b)

result.head(10)
# Out:
#    sessionID        teamID  playerID  attemptID  sessionExtData  \
# 0       7369  hao_jiangang       NaN         17             NaN
# 1       7369  hao_jiangang       NaN         17             NaN
# 2       7369  hao_jiangang       NaN         17             NaN
# 3       7369  hao_jiangang       NaN         17             NaN
# 4       7369  hao_jiangang       NaN         17             NaN
# 5       7369  hao_jiangang       NaN         17             NaN
# 6       7369  hao_jiangang       NaN         17             NaN
# 7       7369  hao_jiangang       NaN         17             NaN
# 8       7369  hao_jiangang       NaN         17             NaN
# 9       7369  hao_jiangang       NaN         17             NaN
#
#    eventSequence eventName        eventStartTime          eventEndTime  \
# 0            NaN      chat  2019-11-06T14:18:31Z  2019-11-06T14:18:31Z
# 1            NaN  question  2019-11-06T14:18:42Z  2019-11-06T14:18:42Z
# ...

# %%
#parse to csv
result.to_csv('XML_Data.csv',index=None)

# %%
#reading csv back in to check my work
csv_check=pd.read_csv('XML_Data.csv')
csv_check
# Out:
#     sessionID        teamID  playerID  attemptID  sessionExtData  \
# 0        7369  hao_jiangang       NaN         17             NaN
# 1        7369  hao_jiangang       NaN         17             NaN
# 2        7369  hao_jiangang       NaN         17             NaN
# 3        7369  hao_jiangang       NaN         17             NaN
# 4        7369  hao_jiangang       NaN         17             NaN
# 5        7369  hao_jiangang       NaN         17             NaN
# 6        7369  hao_jiangang       NaN         17             NaN
# 7        7369  hao_jiangang       NaN         17             NaN
# 8        7369  hao_jiangang       NaN         17             NaN
# 9        7369  hao_jiangang       NaN         17             NaN
# 10       7369  hao_jiangang       NaN         17             NaN
# 11       7369  hao_jiangang       NaN         17             NaN
# 12       7369  hao_jiangang       NaN         17             NaN
# ...
